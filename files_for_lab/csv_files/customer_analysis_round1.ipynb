# %% [markdown]
# ## Read the three files into python as dataframes

# %%
import numpy as np
import pandas as pd


file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %% [markdown]
# ## Concatenate the three dataframes

# %%
df = pd.concat([file1,file2,file3], axis=0)

# %% [markdown]
# ## Show the DataFrame's shape

# %%
file1.shape, file2.shape, file3.shape
# Out:
# ((4008, 11), (996, 11), (7070, 11))

# %%
df.shape
# Out:
# (12074, 13)

# %% [markdown]
# ## Standardize header names.

# %%
cols = []
for column in df.columns:
    cols.append(column.lower())
df.columns = cols

# # renaming columns
# df = df.rename(columns={'controln':'id',
#                             'hv1':'median_home_val', 
#                             'ic1':'median_household_income'})
df.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount state gender
# 0  Four-Door Car            2.704934   NaN    NaN
# 1  Four-Door Car         1131.464935   NaN    NaN
# 2   Two-Door Car          566.472247   NaN    NaN
# 3            SUV          529.881344   NaN    NaN
# 4  Four-Door Car           17.269323   NaN    NaN

# %% [markdown]
# ## Rearrange the columns in the dataframe as needed

# %%
df = df.loc[:,~df.columns.duplicated()]
# Two ways to do it
df.drop(['state'], axis=1, inplace=True)
# del df['state']
df0 = df.rename(columns={'st':'state'})
df0
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065             23405.98798  71941.0                  73.0
# 7066             3096.511217  21604.0                  79.0
# 7067             8163.890428      0.0                  85.0
# 7068             7524.442436  21941.0                  96.0
# 7069             2611.836866      0.0                  77.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [12074 rows x 11 columns]

# %% [markdown]
# ## Which columns are numerical and which ones are categorical?

# %%
df0.dtypes

# Numerical columns: income, monthly premium auto, total claim amount 
# Categorical columns: the rest
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %% [markdown]
# ## Delete the column education and the number of open complaints from the dataframe.

# %%
df0.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
df0.drop(['education'], axis=1, inplace=True)
df0.drop(['number of open complaints'], axis=1, inplace=True)
df0
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN             23405.98798  71941.0
# 7066  PK87824         NaN    NaN             3096.511217  21604.0
# 7067  TD14365         NaN    NaN             8163.890428      0.0
# 7068  UP19263         NaN    NaN             7524.442436  21941.0
# 7069  Y167826         NaN    NaN             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 9 columns]

# %% [markdown]
# ## Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
df0.columns
# Out:
# Index(['customer', 'state', 'gender', 'customer lifetime value', 'income',
#        'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
# We remove the & symbol
df0["customer lifetime value"] = df0["customer lifetime value"].str.replace('\%', '', regex=True)
# We transform the data from object to numeric in order to operate
df0['customer lifetime value'] =  pd.to_numeric(df0['customer lifetime value'], errors='coerce')

df0['customer lifetime value'] = list((map(lambda x: np.dot(x,100), df0['customer lifetime value'])))
df0
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F               69795359.0      0.0
# 2     AI49188      Nevada      F              128874317.0  48767.0
# 3     WW63253  California      M               76458618.0      0.0
# 4     GA49547  Washington      M               53630765.0  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316         NaN    NaN                      NaN  71941.0
# 7066  PK87824         NaN    NaN                      NaN  21604.0
# 7067  TD14365         NaN    NaN                      NaN      0.0
# 7068  UP19263         NaN    NaN                      NaN  21941.0
# 7069  Y167826         NaN    NaN                      NaN      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 9 columns]

# %% [markdown]
# ## Check for duplicate rows in the data and remove if any

# %%
df0.shape
# Out:
# (12074, 9)

# %%
df0.drop_duplicates(inplace=True)
df0.shape
# Out:
# (9135, 9)

# %% [markdown]
# ## Filter out the data for customers who have an income of 0 or less

# %%
df0
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F               69795359.0      0.0
# 2     AI49188      Nevada      F              128874317.0  48767.0
# 3     WW63253  California      M               76458618.0      0.0
# 4     GA49547  Washington      M               53630765.0  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316         NaN    NaN                      NaN  71941.0
# 7066  PK87824         NaN    NaN                      NaN  21604.0
# 7067  TD14365         NaN    NaN                      NaN      0.0
# 7068  UP19263         NaN    NaN                      NaN  21941.0
# 7069  Y167826         NaN    NaN                      NaN      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# 3                    106.0  Corporate Auto            SUV          529.881344
# 4                     68.0   Personal Auto  Four-Door Car           17.269323
# ...                    ...             ...            ...                 ...
# 7065                  73.0   Personal Auto  Four-Door Car          198.234764
# 7066                  79.0  Corporate Auto  Four-Door Car          379.200000
# 7067                  85.0  Corporate Auto  Four-Door Car          790.784983
# 7068                  96.0   Personal Auto  Four-Door Car          691.200000
# 7069                  77.0  Corporate Auto   Two-Door Car          369.600000
#
# [9135 rows x 9 columns]

# %%
df0.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
# df0 = df0.drop(df0['customer']<=0, inplace=False)
# df0.drop(df0[df0['customer'] <= 0].index, inplace=True)
df0['customer'] = list(map(lambda x: x.upper(), df0['customer']))
# df.drop(df[df['Fee'] >= 24000].index, inplace = True)

df0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\JT\OneDrive - UNIR\Certificaciones\IronHack\IH-Labs\Week1\Day 2\lab-customer-analysis-round-1\files_for_lab\csv_files\customer_analysis_round1.ipynb Celda 26 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # df0 = df0.drop(df0['customer']<=0, inplace=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> # df0.drop(df0[df0['customer'] <= 0].index, inplace=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> df0['customer'] = list(map(lambda x: x.upper(), df0['customer']))
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> # df.drop(df[df['Fee'] >= 24000].index, inplace = True)
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> df0
#
# c:\Users\JT\OneDrive - UNIR\Certificaciones\IronHack\IH-Labs\Week1\Day 2\lab-customer-analysis-round-1\files_for_lab\csv_files\customer_analysis_round1.ipynb Celda 26 in <lambda>(x)
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # df0 = df0.drop(df0['customer']<=0, inplace=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> # df0.drop(df0[df0['customer'] <= 0].index, inplace=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> df0['customer'] = list(map(lambda x: x.upper(), df0['customer']))
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> # df.drop(df[df['Fee'] >= 24000].index, inplace = True)
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/Day%202/lab-customer-analysis-round-1/files_for_lab/csv_files/customer_analysis_round1.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> df0
#
# AttributeError: 'float' object has no attribute 'upper'
