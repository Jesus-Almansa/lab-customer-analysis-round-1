# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv("files_for_lab/file1.csv")
df1 = pd.read_csv("files_for_lab/file2.csv")
df2 = pd.read_csv("files_for_lab/file3.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\JT\OneDrive - UNIR\Certificaciones\IronHack\IH-Labs\Week1\lab-customer-analysis-round-1\files_for_lab\repaso.ipynb Celda 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/lab-customer-analysis-round-1/files_for_lab/repaso.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df0 = pd.read_csv("files_for_lab/file1.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/JT/OneDrive%20-%20UNIR/Certificaciones/IronHack/IH-Labs/Week1/lab-customer-analysis-round-1/files_for_lab/repaso.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df1 = pd.read_csv("files_for_lab/file2.csv")
# ...

# %% [markdown]
# #### Read the three files into python as dataframes

# %%
df0
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# #### Show the DataFrame's shape

# %%
df0.shape, df1.shape, df2.shape
# Out:
# ((4008, 11), (996, 11), (7070, 11))

# %% [markdown]
# #### Rearrange the columns in the dataframe as needed & Standardize header names

# %%
df0.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
list = [df0, df1, df2]
for i in list:
    i.columns = ['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
            'income', 'monthly_premium_auto', 'number_of_open_complaints',
            'policy_type', 'vehicleclass', 'total_claim_amount']

# %%
for i in list:
    display(i.head())
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#     vehicleclass  total_claim_amount
# ...

# %% [markdown]
# #### Concatenate the three dataframes

# %%
df = pd.concat([df0, df1, df2], axis=0)
df
# Out:
#      customer       state       gender             education  \
# 0     RB50392  Washington          NaN                Master
# 1     QZ44356     Arizona            F              Bachelor
# 2     AI49188      Nevada            F              Bachelor
# 3     WW63253  California            M              Bachelor
# 4     GA49547  Washington            M  High School or Below
# ...       ...         ...          ...                   ...
# 7065  LA72316  California  23405.98798              Bachelor
# 7066  PK87824  California  3096.511217               College
# 7067  TD14365  California  8163.890428              Bachelor
# 7068  UP19263  California  7524.442436               College
# 7069  Y167826  California  2611.836866               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %% [markdown]
# #### Which columns are numerical?

# %% [markdown]
# #### Which columns are categorical?

# %% [markdown]
# #### Understand the meaning of all columns
